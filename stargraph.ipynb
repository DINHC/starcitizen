# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import random

# %%
starpath = "data/starcitizen1.csv"
starset = pd.read_csv(starpath)

# %%
starset
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# ...

# %%
starset1 = starset.drop(41)
starset1
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# ...

# %%
starset1 = starset1.drop(54)
starset1
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# ...

# %%
starset1['Size'].value_counts()
# Out:
# Small      73
# Large      39
# Medium     29
# Capital    21
# Snub        6
# Name: Size, dtype: int64

# %%
# ship = pd.DataFrame(starset1.groupby(["Role"]).count()).reset_index()
# ship_df = ship[["Role", "Size"]]
# ship_df = ship_df.set_index("Role")

# %%
# starset1.plot(kind="bar")

# plt.title("Size and Role")
# plt.show()
# plt.tight_layout() 
#graph failed need to create new df using data on just ship roles and size

# %%
starset1 = starset1.drop(["Unnamed: 0"],axis=1)
starset1
# Out:
#                   Name    Size                         Role  SCM(m/s)  \
# 0                 100i   Small              Starter;Touring     210.0
# 1                 125a   Small        Starter;Light Fighter     230.0
# 2                 135c   Small        Starter;Light Freight     190.0
# 3                 300i   Small                      Touring     204.0
# 4                 315p   Small                   Pathfinder     210.0
# ..                 ...     ...                          ...       ...
# 165  Vanguard Sentinel  Medium                 Interdiction     230.0
# 166    Vanguard Warden  Medium                Heavy Fighter     225.0
# 167               Void   Large                 Heavy Bomber      85.0
# 168             Vulcan  Medium  Medium Repair;Medium Refuel     210.0
# 169            Vulture   Small                Light Salvage     165.0
#
#      Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  Height(m)  \
# ...

# %%
x = starset1['Size']
y = starset1['Boost(m/s)']
plt.bar(x, y)
plt.xlabel('Size')
plt.ylabel('Boost(m/s)')

plt.title("Size and Speed")

plt.show()

# %%
x = starset1['Size']
y = starset1['SCM(m/s)']
plt.bar(x, y)
plt.xlabel('Size')
plt.ylabel('SCM(m/s)')

plt.title("Size and Combat Speed")

plt.show()

# %%
starpie = (starset1.groupby(['Size'])['Crew max'].count()).tolist()

starpie
# Out:
# [21, 39, 29, 73, 6]

# %%
labels = ["Capital", "Large","Medium" ,'Small', "Snub"]
colors = ["blue", "yellow", 'red', 'green', 'purple']

# %%
plt.rcParams["figure.facecolor"] = 'w'
plt.pie(starpie, labels=labels, colors=colors, autopct="%1.2f%%", shadow=True, startangle=200)
plt.axis("equal")
# Out:
# (-1.1218967785102747,
#  1.1022099664031106,
#  -1.1308052920900795,
#  1.1228761290089877)

# %%
starset2 = starset1

# %%
s = "Crime Type Summer|Crime Type Winter".split("|")

# Generate dummy data into a dataframe
j = {x: [random.choice(["SCM(m/s)", "Boost(m/s)", "SCU(kg)", "Crew max"]
                       ) for j in range(2000)] for x in s}
starset2 = starset2.DataFrame(j)

index = np.arange(5)
bar_width = 0.35

fig, ax = plt.subplots()
large = ax.bar(index, starset2["Large"].value_counts(), bar_width,
                label="Large")

capital = ax.bar(index+bar_width, starset2["Capital"].value_counts(),
                 bar_width, label="Capital")

ax.set_xlabel('Category')
ax.set_ylabel('Amount')
ax.set_title('Large vs Capital Ships, type')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(["SCM(m/s)", "Boost(m/s)", "SCU(kg)", "Crew max"])
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-b1a5355f2ae8> in <module>
#       4 j = {x: [random.choice(["SCM(m/s)", "Boost(m/s)", "SCU(kg)", "Crew max"]
#       5                        ) for j in range(2000)] for x in s}
# ----> 6 starset2 = starset2.DataFrame(j)
#       7
#       8 index = np.arange(5)
#
# c:\Users\dinhc\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
starlarge = starset1.loc[starset1['Size']== 'Large']
starlarge

# %%
starlarge.plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Large Ships and Speed")

plt.show()

# %%
starlarge.to_csv('starlarge.csv')

# %%
starmed = starset1.loc[starset1['Size']== 'Medium']
starmed

# %%
starmed.to_csv('starmed.csv')

# %%
starsmall = starset1.loc[starset1['Size'] == 'Small']
starsmall

# %%
starsmall.to_csv('starsmall.csv')

# %%
starcapital = starset1.loc[starset1['Size'] == 'Capital']
starcapital

# %%
starcapital.to_csv('starcapital.csv')
