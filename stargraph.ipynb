# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
starpath = "data/starcitizen1.csv"
starset = pd.read_csv(starpath)

# %%
starset
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# 0       210.0      1000.0       2       1.0       1.0      19.3     11.0
# 1       230.0      1150.0       2       1.0       1.0      19.3     11.0
# 2       190.0      1095.0       6       1.0       1.0      19.3     11.0
# 3       204.0      1190.0       8       1.0       1.0        27     17.0
# 4       210.0      1225.0      12       1.0       1.0        27     17.0
# ..        ...         ...     ...       ...       ...       ...      ...
# 165     230.0      1022.0       0       2.0       2.0        38     26.5
# 166     225.0      1115.0       0       2.0       2.0        38     26.5
# 167      85.0       900.0       0       1.0       5.0       124     90.0
# 168     210.0      1180.0      12       1.0       3.0      38.5     16.5
# 169     165.0      1215.0      12       1.0       1.0        33     16.0
#
#      Height(m)   Mass(kg)        Status Manufacturer  \
# 0          4.0   48143.00  Flight Ready         ORIG
# 1          4.0   48143.00  Flight Ready         ORIG
# 2          4.0   48143.00  Flight Ready         ORIG
# 3          8.0   66320.00  Flight Ready         ORIG
# 4          8.0   69220.00  Flight Ready         ORIG
# ..         ...        ...           ...          ...
# 165        9.5  238616.00  Flight Ready         AEGS
# 166        9.5  256409.25  Flight Ready         AEGS
# 167       33.0  106460.00    Production         VNCL
# 168       10.0  625330.00     Announced         AEGS
# 169        9.0  114591.00    Production         DRAK
#
#                               Patch release
# 0                                       NaN
# 1                                       NaN
# 2                              Alpha 3.11.0
# 3    Patch 1 (Original)Alpha 3.5.0 (Rework)
# 4    Patch 1 (Original)Alpha 3.5.1 (Rework)
# ..                                      ...
# 165                             Alpha 3.7.0
# 166                             Alpha 2.1.0
# 167                                     NaN
# 168                                     TBA
# 169                                     TBA
#
# [170 rows x 16 columns]

# %%
starset1 = starset.drop(41)
starset1
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# 0       210.0      1000.0       2       1.0       1.0      19.3     11.0
# 1       230.0      1150.0       2       1.0       1.0      19.3     11.0
# 2       190.0      1095.0       6       1.0       1.0      19.3     11.0
# 3       204.0      1190.0       8       1.0       1.0        27     17.0
# 4       210.0      1225.0      12       1.0       1.0        27     17.0
# ..        ...         ...     ...       ...       ...       ...      ...
# 165     230.0      1022.0       0       2.0       2.0        38     26.5
# 166     225.0      1115.0       0       2.0       2.0        38     26.5
# 167      85.0       900.0       0       1.0       5.0       124     90.0
# 168     210.0      1180.0      12       1.0       3.0      38.5     16.5
# 169     165.0      1215.0      12       1.0       1.0        33     16.0
#
#      Height(m)   Mass(kg)        Status Manufacturer  \
# 0          4.0   48143.00  Flight Ready         ORIG
# 1          4.0   48143.00  Flight Ready         ORIG
# 2          4.0   48143.00  Flight Ready         ORIG
# 3          8.0   66320.00  Flight Ready         ORIG
# 4          8.0   69220.00  Flight Ready         ORIG
# ..         ...        ...           ...          ...
# 165        9.5  238616.00  Flight Ready         AEGS
# 166        9.5  256409.25  Flight Ready         AEGS
# 167       33.0  106460.00    Production         VNCL
# 168       10.0  625330.00     Announced         AEGS
# 169        9.0  114591.00    Production         DRAK
#
#                               Patch release
# 0                                       NaN
# 1                                       NaN
# 2                              Alpha 3.11.0
# 3    Patch 1 (Original)Alpha 3.5.0 (Rework)
# 4    Patch 1 (Original)Alpha 3.5.1 (Rework)
# ..                                      ...
# 165                             Alpha 3.7.0
# 166                             Alpha 2.1.0
# 167                                     NaN
# 168                                     TBA
# 169                                     TBA
#
# [169 rows x 16 columns]

# %%
starset1 = starset1.drop(54)
starset1
# Out:
#      Unnamed: 0               Name    Size                         Role  \
# 0             0               100i   Small              Starter;Touring
# 1             1               125a   Small        Starter;Light Fighter
# 2             2               135c   Small        Starter;Light Freight
# 3             3               300i   Small                      Touring
# 4             4               315p   Small                   Pathfinder
# ..          ...                ...     ...                          ...
# 165         165  Vanguard Sentinel  Medium                 Interdiction
# 166         166    Vanguard Warden  Medium                Heavy Fighter
# 167         167               Void   Large                 Heavy Bomber
# 168         168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169         169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# 0       210.0      1000.0       2       1.0       1.0      19.3     11.0
# 1       230.0      1150.0       2       1.0       1.0      19.3     11.0
# 2       190.0      1095.0       6       1.0       1.0      19.3     11.0
# 3       204.0      1190.0       8       1.0       1.0        27     17.0
# 4       210.0      1225.0      12       1.0       1.0        27     17.0
# ..        ...         ...     ...       ...       ...       ...      ...
# 165     230.0      1022.0       0       2.0       2.0        38     26.5
# 166     225.0      1115.0       0       2.0       2.0        38     26.5
# 167      85.0       900.0       0       1.0       5.0       124     90.0
# 168     210.0      1180.0      12       1.0       3.0      38.5     16.5
# 169     165.0      1215.0      12       1.0       1.0        33     16.0
#
#      Height(m)   Mass(kg)        Status Manufacturer  \
# 0          4.0   48143.00  Flight Ready         ORIG
# 1          4.0   48143.00  Flight Ready         ORIG
# 2          4.0   48143.00  Flight Ready         ORIG
# 3          8.0   66320.00  Flight Ready         ORIG
# 4          8.0   69220.00  Flight Ready         ORIG
# ..         ...        ...           ...          ...
# 165        9.5  238616.00  Flight Ready         AEGS
# 166        9.5  256409.25  Flight Ready         AEGS
# 167       33.0  106460.00    Production         VNCL
# 168       10.0  625330.00     Announced         AEGS
# 169        9.0  114591.00    Production         DRAK
#
#                               Patch release
# 0                                       NaN
# 1                                       NaN
# 2                              Alpha 3.11.0
# 3    Patch 1 (Original)Alpha 3.5.0 (Rework)
# 4    Patch 1 (Original)Alpha 3.5.1 (Rework)
# ..                                      ...
# 165                             Alpha 3.7.0
# 166                             Alpha 2.1.0
# 167                                     NaN
# 168                                     TBA
# 169                                     TBA
#
# [168 rows x 16 columns]

# %%
starset1['Size'].value_counts()
# Out:
# Small      73
# Large      39
# Medium     29
# Capital    21
# Snub        6
# Name: Size, dtype: int64

# %%
# ship = pd.DataFrame(starset1.groupby(["Role"]).count()).reset_index()
# ship_df = ship[["Role", "Size"]]
# ship_df = ship_df.set_index("Role")

# %%
# starset1.plot(kind="bar")

# plt.title("Size and Role")
# plt.show()
# plt.tight_layout() 
#graph failed need to create new df using data on just ship roles and size

# %%
# starset1[['Role', 'Mass(kg)']].plot()
x = starset1['Size']
y = starset1['Boost(m/s)']
plt.bar(x, y)
plt.xlabel('Size')
plt.ylabel('Boost(m/s)')

plt.title("Size and Speed")

plt.show()

#Messy

# %%
starloc = starset1.loc[starset1['Size']== 'Large']
starloc
# Out:
#      Unnamed: 0                               Name   Size  \
# 7             7                               400i  Large
# 8             8             600i Executive-Edition  Large
# 9             9                      600i Explorer  Large
# 10           10                       600i Touring  Large
# 13           13             A2 Hercules Starlifter  Large
# 14           14                     Apollo Medivac  Large
# 15           15                      Apollo Triage  Large
# 32           32             C2 Hercules Starlifter  Large
# 35           35                            Carrack  Large
# 36           36  Carrack Best in Show 2950 Edition  Large
# 37           37                 Carrack Expedition  Large
# 38           38                        Caterpillar  Large
# 39           39   Caterpillar Best In Show Edition  Large
# 40           40         Caterpillar Pirate Edition  Large
# 42           42            Constellation Andromeda  Large
# 43           43               Constellation Aquila  Large
# 44           44              Constellation Phoenix  Large
# 45           45      Constellation Phoenix Emerald  Large
# 46           46               Constellation Taurus  Large
# 47           47                            Corsair  Large
# 48           48                           Crucible  Large
# 77           77                  Genesis Starliner  Large
# 82           82                         Hammerhead  Large
# 83           83    Hammerhead Best In Show Edition  Large
# 88           88                             Hull C  Large
# 101         101                          Liberator  Large
# 102         102             M2 Hercules Starlifter  Large
# 110         110                        Merchantman  Large
# 118         118                           Nautilus  Large
# 119         119                  Nautilus Solstice  Large
# 121         121                            Odyssey  Large
# 127         127                            Perseus  Large
# 138         138                          Reclaimer  Large
# 139         139     Reclaimer Best In Show Edition  Large
# 145         145                    Retaliator Base  Large
# 146         146                  Retaliator Bomber  Large
# 155         155                          Starfarer  Large
# 156         156                   Starfarer Gemini  Large
# 167         167                               Void  Large
#
#                        Role  SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max  \
# 7                Pathfinder     184.0      1249.0      42       1.0       3.0
# 8                Expedition     145.0       975.0      40       2.0       5.0
# 9                Expedition     145.0       975.0      40       2.0       5.0
# 10                  Touring     135.0       950.0      16       3.0       5.0
# 13        Transport Gunship     135.0       961.0     216       1.0       8.0
# 14        Support - Medical     195.0      1100.0      28       1.0       2.0
# 15        Support - Medical     205.0      1210.0      28       1.0       2.0
# 32                Transport     135.0       962.0     696       NaN       2.0
# 35               Expedition     208.0      1076.0     456       4.0       6.0
# 36               Expedition     208.0      1076.0     456       4.0       6.0
# 37               Expedition     208.0      1076.0     456       4.0       6.0
# 38                Transport     130.0       890.0     564       2.0       4.0
# 39                Transport     130.0       890.0     564       2.0       4.0
# 40                Transport     130.0       890.0     564       2.0       4.0
# 42   Medium Freight;Gunship     190.0       910.0      96       3.0       4.0
# 43               Expedition     190.0       985.0      96       3.0       4.0
# 44                  Touring     120.0       900.0      96       3.0       4.0
# 45                  Touring     120.0       900.0      96       3.0       4.0
# 46           Medium Freight     114.0       911.0     174       3.0       4.0
# 47              Exploration     160.0       950.0      72       1.0       4.0
# 48             Heavy Repair     140.0       900.0     230       3.0       8.0
# 77                Passenger     160.0       950.0     300       2.0       8.0
# 82            Heavy Gunship     105.0      1000.0      40       3.0       8.0
# 83            Heavy Gunship     105.0      1000.0      40       3.0       8.0
# 88            Heavy Freight      90.0       900.0   4,608       2.0       4.0
# 101             Transporter     115.0       970.0     400       1.0       2.0
# 102      Transport Military     130.0       962.0     522       1.0       3.0
# 110           Heavy Freight     200.0      1150.0    2880       4.0       8.0
# 118               Minelayer     115.0       950.0      64       4.0       8.0
# 119               Minelayer     115.0       950.0      64       4.0       8.0
# 121              Expedition      70.0       950.0     252       1.0       6.0
# 127                 Gunship      92.0      1120.0      50       6.0       6.0
# 138           Heavy Salvage     100.0       930.0     180       4.0       5.0
# 139           Heavy Salvage     100.0       930.0     180       4.0       5.0
# 145            Heavy Bomber     185.0       815.0       0       4.0       7.0
# 146            Heavy Bomber     145.0       814.0       0       4.0       7.0
# 155        Heavy Refuelling      85.0       890.0     291       4.0       8.0
# 156        Heavy Refuelling      85.0       890.0     291       4.0       6.0
# 167            Heavy Bomber      85.0       900.0       0       1.0       5.0
#
#     Length(m)  Beam(m)  Height(m)     Mass(kg)        Status Manufacturer  \
# 7          60     32.0       12.5    455927.06  Flight Ready         ORIG
# 8        91.5     52.0       17.0   1576792.00  Flight Ready         ORIG
# 9        91.5     52.0       17.0   1626251.25  Flight Ready         ORIG
# 10       91.5     52.0       17.0   1576792.00  Flight Ready         ORIG
# 13         94     70.0       23.0   3191991.75  Flight Ready         CRSD
# 14         43     30.0       10.0    376500.00     Announced          RSI
# 15         43     30.0       10.0    376500.00     Announced          RSI
# 32         94     70.0       23.0   3193461.00  Flight Ready         CRSD
# 35      126.5     76.5       30.0   4397858.00  Flight Ready         ANVL
# 36      126.5     76.5       30.0   4397858.00  Flight Ready         ANVL
# 37      126.5     76.5       30.0   4397858.00  Flight Ready         ANVL
# 38      111.5     39.0       13.5   1673626.25  Flight Ready         DRAK
# 39      111.5     39.0       13.5   1608205.00  Flight Ready         DRAK
# 40      111.5     39.0       13.5   1608205.00  Flight Ready         DRAK
# 42         61     26.0       14.0    436531.22  Flight Ready          RSI
# 43         61     26.0       14.0    453823.25  Flight Ready          RSI
# 44         61     26.0       14.0    417510.00  Flight Ready          RSI
# 45         61     26.0       14.0    417510.00  Flight Ready          RSI
# 46         61     26.0       14.0    431529.28  Flight Ready          RSI
# 47         55     27.0       31.0    434629.00    Production         DRAK
# 48         90     50.0       20.0   3650500.00     Announced         ANVL
# 77         85     90.0       16.0   3120000.00     Announced         CRSD
# 82        115     75.0       16.0   4630030.00  Flight Ready         AEGS
# 83        115     75.0       16.0   4260000.00  Flight Ready         AEGS
# 88        125     55.0       55.0    886930.00    Production         MISC
# 101       119     67.0       25.0   2600820.00     Announced         ANVL
# 102        94     70.0       23.0   3139240.00  Flight Ready         CRSD
# 110       160    160.0       65.0   9635000.00    Production         SOUL
# 118       125     72.0       21.6  13526320.00     Announced         AEGS
# 119       125     72.0       21.6  13526320.00     Announced         AEGS
# 121       140     90.0       35.0    453823.00     Announced         MISC
# 127       100     50.0       21.0   3560000.00       Concept          RSI
# 138       155    118.0       50.0   9500158.00  Flight Ready         AEGS
# 139       155    118.0       50.0   9500158.00  Flight Ready         AEGS
# 145      69.5     42.5       12.5    300392.00    Production         AEGS
# 146      69.5     42.5       12.5    348634.34  Flight Ready         AEGS
# 155       101     46.5       23.5   3510025.00  Flight Ready         MISC
# 156       101     46.5       23.5   3517864.00  Flight Ready         MISC
# 167       124     90.0       33.0    106460.00    Production         VNCL
#
#     Patch release
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 13            NaN
# 14            TBA
# 15            TBA
# 32            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 42            NaN
# 43            NaN
# 44    Alpha 3.3.0
# 45    Alpha 3.4.0
# 46            NaN
# 47            TBA
# 48            TBA
# 77            TBA
# 82    Alpha 3.3.0
# 83            NaN
# 88            NaN
# 101           NaN
# 102           NaN
# 110           NaN
# 118           TBA
# 119           TBA
# 121           NaN
# 127           TBA
# 138   Alpha 3.1.0
# 139             ?
# 145           TBA
# 146           NaN
# 155           NaN
# 156           NaN
# 167           NaN

# %%
starloc.plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Size and Speed")

plt.show()

# %%
x = starset1['Size']
y = starset1['SCM(m/s)']
plt.bar(x, y)
plt.xlabel('Size')
plt.ylabel('SCM(m/s)')

plt.title("Size and Combat Speed")

plt.show()

# %%
starpie = (starset1.groupby(['Size'])['Crew max'].count()).tolist()

starpie
# Out:
# [21, 39, 29, 73, 6]

# %%
labels = ["Capital", "Large","Medium" ,'Small', "Snub"]
colors = ["blue", "yellow", 'red', 'green', 'purple']

# %%
plt.pie(starpie, labels=labels, colors=colors, autopct="%1.2f%%", shadow=True, startangle=200)
plt.axis("equal")
# Out:
# (-1.1218967785102747,
#  1.1022099664031106,
#  -1.1308052920900795,
#  1.1228761290089877)
