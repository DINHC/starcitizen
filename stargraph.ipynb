# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import random

# %%
starpath = "data/starset1.csv"
starset = pd.read_csv(starpath)

# %%
starset
# Out:
#      Unnamed: 0.1  Unnamed: 0               Name    Size  \
# 0               0           0               100i   Small
# 1               1           1               125a   Small
# 2               2           2               135c   Small
# 3               3           3               300i   Small
# 4               4           4               315p   Small
# ..            ...         ...                ...     ...
# 165           165         165  Vanguard Sentinel  Medium
# 166           166         166    Vanguard Warden  Medium
# 167           167         167               Void   Large
# 168           168         168             Vulcan  Medium
# 169           169         169            Vulture   Small
#
#                             Role  SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  \
# 0                Starter;Touring     210.0      1000.0       2       1.0
# 1          Starter;Light Fighter     230.0      1150.0       2       1.0
# ...

# %%
starset1 = starset.drop(41)
starset1
# Out:
#      Unnamed: 0.1  Unnamed: 0               Name    Size  \
# 0               0           0               100i   Small
# 1               1           1               125a   Small
# 2               2           2               135c   Small
# 3               3           3               300i   Small
# 4               4           4               315p   Small
# ..            ...         ...                ...     ...
# 165           165         165  Vanguard Sentinel  Medium
# 166           166         166    Vanguard Warden  Medium
# 167           167         167               Void   Large
# 168           168         168             Vulcan  Medium
# 169           169         169            Vulture   Small
#
#                             Role  SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  \
# 0                Starter;Touring     210.0      1000.0       2       1.0
# 1          Starter;Light Fighter     230.0      1150.0       2       1.0
# ...

# %%
starset1 = starset1.drop(54)
starset1
# Out:
#      Unnamed: 0.1  Unnamed: 0               Name    Size  \
# 0               0           0               100i   Small
# 1               1           1               125a   Small
# 2               2           2               135c   Small
# 3               3           3               300i   Small
# 4               4           4               315p   Small
# ..            ...         ...                ...     ...
# 165           165         165  Vanguard Sentinel  Medium
# 166           166         166    Vanguard Warden  Medium
# 167           167         167               Void   Large
# 168           168         168             Vulcan  Medium
# 169           169         169            Vulture   Small
#
#                             Role  SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  \
# 0                Starter;Touring     210.0      1000.0       2       1.0
# 1          Starter;Light Fighter     230.0      1150.0       2       1.0
# ...

# %%
starset1['Size'].value_counts()
# Out:
# Small      73
# Large      39
# Medium     29
# Capital    21
# Snub        6
# Name: Size, dtype: int64

# %%
# ship = pd.DataFrame(starset1.groupby(["Role"]).count()).reset_index()
# ship_df = ship[["Role", "Size"]]
# ship_df = ship_df.set_index("Role")

# %%
# starset1.plot(kind="bar")

# plt.title("Size and Role")
# plt.show()
# plt.tight_layout() 
#graph failed need to create new df using data on just ship roles and size

# %%
starset1 = starset1.drop(["Unnamed: 0"],axis=1)
starset1
# Out:
#      Unnamed: 0.1               Name    Size                         Role  \
# 0               0               100i   Small              Starter;Touring
# 1               1               125a   Small        Starter;Light Fighter
# 2               2               135c   Small        Starter;Light Freight
# 3               3               300i   Small                      Touring
# 4               4               315p   Small                   Pathfinder
# ..            ...                ...     ...                          ...
# 165           165  Vanguard Sentinel  Medium                 Interdiction
# 166           166    Vanguard Warden  Medium                Heavy Fighter
# 167           167               Void   Large                 Heavy Bomber
# 168           168             Vulcan  Medium  Medium Repair;Medium Refuel
# 169           169            Vulture   Small                Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# ...

# %%
starset1 = starset1.drop(["Unnamed: 0.1"],axis=1)
starset1
# Out:
#                   Name    Size                         Role  SCM(m/s)  \
# 0                 100i   Small              Starter;Touring     210.0
# 1                 125a   Small        Starter;Light Fighter     230.0
# 2                 135c   Small        Starter;Light Freight     190.0
# 3                 300i   Small                      Touring     204.0
# 4                 315p   Small                   Pathfinder     210.0
# ..                 ...     ...                          ...       ...
# 165  Vanguard Sentinel  Medium                 Interdiction     230.0
# 166    Vanguard Warden  Medium                Heavy Fighter     225.0
# 167               Void   Large                 Heavy Bomber      85.0
# 168             Vulcan  Medium  Medium Repair;Medium Refuel     210.0
# 169            Vulture   Small                Light Salvage     165.0
#
#      Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  Height(m)  \
# ...

# %%
starset1 = starset1.drop(["Patch release"],axis=1)
starset1
# Out:
#                   Name    Size                         Role  SCM(m/s)  \
# 0                 100i   Small              Starter;Touring     210.0
# 1                 125a   Small        Starter;Light Fighter     230.0
# 2                 135c   Small        Starter;Light Freight     190.0
# 3                 300i   Small                      Touring     204.0
# 4                 315p   Small                   Pathfinder     210.0
# ..                 ...     ...                          ...       ...
# 165  Vanguard Sentinel  Medium                 Interdiction     230.0
# 166    Vanguard Warden  Medium                Heavy Fighter     225.0
# 167               Void   Large                 Heavy Bomber      85.0
# 168             Vulcan  Medium  Medium Repair;Medium Refuel     210.0
# 169            Vulture   Small                Light Salvage     165.0
#
#      Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  Height(m)  \
# ...

# %%
starset1 = starset1.dropna()

# %%
starset1.columns
# Out:
# Index(['Name', 'Size', 'Role', 'SCM(m/s)', 'Boost(m/s)', 'SCU(kg)', 'Crew min',
#        'Crew max', 'Length(m)', 'Beam(m)', 'Height(m)', 'Mass(kg)', 'Status',
#        'Manufacturer', 'Cost (Dollars)'],
#       dtype='object')

# %%
x = starset1['Size']
y = starset1['Boost(m/s)']
plt.bar(x,y)
plt.xlabel('Size')
plt.ylabel('Boost(m/s)')

plt.title("Size and Avg Speed")

#plt.savefig("graphs/size&avgspeed")
plt.show()

# %%
x = starset1['Size']
y = starset1['Boost(m/s)']
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.bar((range(len(x))),y , alpha=0.5)
plt.xlabel('Size')
plt.ylabel('Boost(m/s)')

plt.title("Size and Avg Speed")

plt.show()

#failed to sort.

# %%
x = starset1['Size']
y = starset1['SCM(m/s)']
plt.bar(x, y)
plt.xlabel('Size')
plt.ylabel('SCM(m/s)')

plt.title("Size and Combat Speed")

#plt.savefig("graphs/size&combat")

plt.show()

# %%
starpie = (starset1.groupby(['Size'])['Crew max'].count()).tolist()

starpie
# Out:
# [17, 37, 29, 73, 6]

# %%
labels = ["Capital", "Large","Medium" ,'Small', "Snub"]
colors = ["blue", "yellow", 'red', 'green', 'purple']

# %%
plt.rcParams["figure.facecolor"] = 'w'
plt.pie(starpie, labels=labels, colors=colors, autopct="%1.2f%%", shadow=True, startangle=200)
plt.axis("equal")
#plt.savefig("graphs/starpie")

# %%
#Made a copy of df to work on graphs focusing on ship size and speed 
starset2 = starset1

# %%
starlarge = starset2.loc[starset1['Size']== 'Large']
starlarge
# Out:
#                                   Name   Size                    Role  \
# 7                                 400i  Large              Pathfinder
# 8               600i Executive-Edition  Large              Expedition
# 9                        600i Explorer  Large              Expedition
# 10                        600i Touring  Large                 Touring
# 13              A2 Hercules Starlifter  Large       Transport Gunship
# 14                      Apollo Medivac  Large       Support - Medical
# 15                       Apollo Triage  Large       Support - Medical
# 35                             Carrack  Large              Expedition
# 36   Carrack Best in Show 2950 Edition  Large              Expedition
# 37                  Carrack Expedition  Large              Expedition
# 38                         Caterpillar  Large               Transport
# 39    Caterpillar Best In Show Edition  Large               Transport
# ...

# %%
starlarge['Name'].count()
# Out:
# 37

# %%
#In the graph below the 3 fastest large ships are the 400i, Apollo Triage, and Merchantman
#The 2 slowest large ships are Retaliator Base and Bomber 
starlarge.sort_values(by="Boost(m/s)",ascending=False).plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Large Ships and Speed")
#plt.savefig("graphs/large&boost")
plt.show()

# %%
starlarge2 = starlarge.sort_values(by="Boost(m/s)", ascending=False)
starlarge2
# Out:
#                                   Name   Size                    Role  \
# 7                                 400i  Large              Pathfinder
# 15                       Apollo Triage  Large       Support - Medical
# 110                        Merchantman  Large           Heavy Freight
# 127                            Perseus  Large                 Gunship
# 14                      Apollo Medivac  Large       Support - Medical
# 37                  Carrack Expedition  Large              Expedition
# 35                             Carrack  Large              Expedition
# 36   Carrack Best in Show 2950 Edition  Large              Expedition
# 83     Hammerhead Best In Show Edition  Large           Heavy Gunship
# 82                          Hammerhead  Large           Heavy Gunship
# 43                Constellation Aquila  Large              Expedition
# 9                        600i Explorer  Large              Expedition
# ...

# %%
#s1 = starlarge.sort_values(by="Boost(m/s)",ascending=False)


#s1 = starlarge.pivot_table(index='Name', columns='Manufacturer', values="Boost(m/s)",
#                aggfunc='sum', fill_value=0).sort_values(by=["Boost(m/s)"],ascending=False, axis=1).plot.bar(figsize=(20,20),stacked=True)
#s1 = starlarge.groupby('Manufacturer').sum().sort_values(by='Boost(m/s)',ascending=False).index

sun2 = starlarge.pivot(index='Name', columns='Manufacturer', values='Boost(m/s)').plot.bar(figsize=(30,30),stacked=True, subplots =True)


#moon = sun.sort_values(by='Boost(m/s)', ascending=False)
plt.savefig("graphs/manufacturer&boost")
sun2
# Out:
# array([<AxesSubplot: title={'center': 'AEGS'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'ANVL'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'CRSD'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'DRAK'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'MISC'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'ORIG'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'RSI'}, xlabel='Name'>,
#        <AxesSubplot: title={'center': 'SOUL'}, xlabel='Name'>],
#       dtype=object)

# %%
s2 = starlarge2.pivot(index='Name', columns='Manufacturer', values='Boost(m/s)').plot.barh(figsize=(20,20))
s2
# Out:
# <AxesSubplot: ylabel='Name'>

# %%
#The 3 fastest ships in terms of combat speed are Carrack (including variants), Apollo Triage, and Merchantman
#The 3 slowest ships in terms of combat speed are Odyssey, Void, and Starfarer Gemini
starlarge.sort_values(by="SCM(m/s)",ascending=False).plot.bar(x="Name", y ="SCM(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('SCM(m/s)')

plt.title("Large Ships and Combat Speed")

plt.show()

# %%
starmed = starset2.loc[starset2['Size']== 'Medium']
starmed
# Out:
#                                         Name    Size  \
# 16                 Ares Star Fighter Inferno  Medium
# 17                     Ares Star Fighter Ion  Medium
# 49                             Cutlass Black  Medium
# 50        Cutlass Black Best In Show Edition  Medium
# 51   Cutlass Black Best in Show 2950 Edition  Medium
# 52                              Cutlass Blue  Medium
# 53                               Cutlass Red  Medium
# 57                                   Eclipse  Medium
# 58         Eclipse Best in Show 2950 Edition  Medium
# 73                                Freelancer  Medium
# 74                            Freelancer DUR  Medium
# 75                            Freelancer MAX  Medium
# 76                            Freelancer MIS  Medium
# 81                                    Glaive  Medium
# 87                                    Hull B  Medium
# 104                                     MOLE  Medium
# 105                              MOLE Carbon  Medium
# ...

# %%
starmed.sort_values(by="Boost(m/s)",ascending=False).plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Medium Ships and Speed")

plt.show()

# %%
starmed.sort_values(by="SCM(m/s)",ascending=False).plot.bar(x="Name", y ="SCM(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('SCM(m/s)')

plt.title("Medium Ships and Combat Speed")

plt.show()

# %%
starsmall = starset2.loc[starset2['Size'] == 'Small']
starsmall
# Out:
#                                    Name   Size                   Role  \
# 0                                  100i  Small        Starter;Touring
# 1                                  125a  Small  Starter;Light Fighter
# 2                                  135c  Small  Starter;Light Freight
# 3                                  300i  Small                Touring
# 4                                  315p  Small             Pathfinder
# ..                                  ...    ...                    ...
# 159                            Terrapin  Small             Pathfinder
# 160                            Valkyrie  Small    Military;Industrial
# 161  Valkyrie Best in Show 2950 Edition  Small    Military;Industrial
# 162          Valkyrie Liberator Edition  Small    Military;Industrial
# 169                             Vulture  Small          Light Salvage
#
#      SCM(m/s)  Boost(m/s) SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  \
# ...

# %%
starsmall.sort_values(by="Boost(m/s)",ascending=False).plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Small Ships and Speed")

plt.show()

# %%
starsmall.sort_values(by="SCM(m/s)",ascending=False).plot.bar(x="Name", y ="SCM(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('SCM(m/s)')

plt.title("Small Ships and Combat Speed")

plt.show()

# %%
starcapital = starset2.loc[starset2['Size'] == 'Capital']
starcapital
# Out:
#                       Name     Size                        Role  SCM(m/s)  \
# 12                890 Jump  Capital                     Touring      80.0
# 59                Endeavor  Capital               Heavy Science      30.0
# 60      Endeavor Discovery  Capital               Heavy Science      30.0
# 61           Endeavor Hope  Capital               Heavy Science      30.0
# 62        Endeavor Olympic  Capital               Heavy Science      30.0
# 89                  Hull D  Capital               Heavy Freight      60.0
# 90                  Hull E  Capital               Heavy Freight      60.0
# 92                 Idris-K  Capital                     Frigate      45.0
# 93                 Idris-M  Capital                     Frigate      45.0
# 94                 Idris-P  Capital                     Frigate      45.0
# 95                 Javelin  Capital                   Destroyer     200.0
# 98                  Kraken  Capital  Multi-Role - Light Carrier      60.0
# ...

# %%
starcapital.sort_values(by="Boost(m/s)",ascending=False).plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Capital Ships and Speed")

plt.show()

# %%
starcapital.sort_values(by="SCM(m/s)",ascending=False).plot.bar(x="Name", y ="SCM(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('SCM(m/s)')

plt.title("Capital Ships and Combat Speed")

plt.show()

# %%
starsnub = starset2.loc[starset2['Size'] == 'Snub']

# %%
starsnub
# Out:
#                         Name  Size           Role  SCM(m/s)  Boost(m/s)  \
# 11                       85X  Snub        Touring     255.0      1185.0
# 107               MPUV Cargo  Snub  Light Freight     150.0       900.0
# 108           MPUV Personnel  Snub      Passenger     150.0       920.0
# 123              P-52 Merlin  Snub   Snub Fighter     270.0      1030.0
# 124          P-72 Archimedes  Snub         Racing     250.0      1340.0
# 125  P-72 Archimedes Emerald  Snub         Racing     250.0      1340.0
#
#     SCU(kg)  Crew min  Crew max Length(m)  Beam(m)  Height(m)  Mass(kg)  \
# 11        0       1.0       2.0        13     10.0        2.0   19097.0
# 107       2       1.0       1.0       9.5      8.5        4.3   12187.0
# 108       0       1.0       1.0       9.3      8.5        4.3   12307.0
# 123       0       1.0       1.0        12      7.7        2.2    8493.0
# 124       0       1.0       1.0        12      7.7        2.2    8290.0
# ...

# %%
starsnub.sort_values(by="Boost(m/s)",ascending=False).plot.bar(x="Name", y ="Boost(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('Boost(m/s)')

plt.title("Snub Ships and Speed")

plt.show()

# %%
starsnub.sort_values(by="SCM(m/s)",ascending=False).plot.bar(x="Name", y ="SCM(m/s)", rot= 90, figsize=(20,10))
plt.xlabel('Name')
plt.ylabel('SCM(m/s)')

plt.title("Snub Ships and Combat Speed")

plt.show()

# %%
#this is where the graph will focus on the cost of the ships. Parameters will be used to either outline or fight against cost. 
starmoney = starset1
